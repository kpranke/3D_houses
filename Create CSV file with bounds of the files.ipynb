# %%
import pandas as pd
import geopandas as gpd
import rasterio
import rasterio.features
import rasterio.warp
from rasterio.plot import show
#Importing the Nominatim geocoder class 
#from geopy.geocoders import Nominatim
from shapely.geometry import point, Polygon
import rioxarray
from pyproj import CRS
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
import requests
from osgeo import gdal
from osgeo import ogr
import fiona
# %matplotlib inline

# %%
# input the adress of the house
# retrieve a polygoon of the house via api
# create a rectangle which contains the polygoon (top - bottom - left - right)
# search for the correct raster file => the bounds of which raster file contain the rectangle (zipped link)
# calculate a CHM of the correct file

# %%
# create a rectangle which contains the polygoon (top - bottom - left - right)
# search for the correct raster file => the bounds of which raster file contain the rectangle (zipped link)

# %%
# create a list 1-43 with leading zeros, when only one digit [01,02,...,43]
list_43 = list(range(1,44))
updated_list = []
for i in list_43:
    i = str(i)
    i = i.zfill(2)
    updated_list.append(i)

# %%
# save bounds of DTM files in a .csv
DTM_bounds = []

for i in updated_list:
    url_dtm = f'zip+https://downloadagiv.blob.core.windows.net/dhm-vlaanderen-ii-dtm-raster-1m/DHMVIIDTMRAS1m_k{i}.zip!/GeoTIFF/DHMVIIDTMRAS1m_k{i}.tif'
    url_dsm = f'zip+https://downloadagiv.blob.core.windows.net/dhm-vlaanderen-ii-dsm-raster-1m/DHMVIIDSMRAS1m_k{i}.zip!/GeoTIFF/DHMVIIDSMRAS1m_k{i}.tif'
    print(f"Accesssing {i}")
    
    DTM_file = rasterio.open(url_dtm)
    print(f"Opened DTM file {i}")
       
    DTM_bounds.append({
        'url_dtm': url_dtm,
        'url_dsm' : url_dsm,
        'left' : DTM_file.bounds.left,
        'right' : DTM_file.bounds.right,
        'top' : DTM_file.bounds.top,
        'bottom' : DTM_file.bounds.bottom
    })
    print(f"Added bounds of DTM file {i}")
    
DTM_bounds_df = pd.DataFrame.from_dict(DTM_bounds)
DTM_bounds_df.to_csv('DTM_bounds.csv', encoding='utf-8', index=False)
# Out:
# Accesssing 01
# Opened DTM file 01
# Opened DSM file 01
# Added bounds of DTM file 01
# Accesssing 02
# Opened DTM file 02
# Opened DSM file 02
# Added bounds of DTM file 02
# Accesssing 03
# Opened DTM file 03
# Opened DSM file 03
# Added bounds of DTM file 03
# Accesssing 04
# Opened DTM file 04
# Opened DSM file 04
# Added bounds of DTM file 04
# Accesssing 05
# Opened DTM file 05
# Opened DSM file 05
# Added bounds of DTM file 05
# Accesssing 06
# Opened DTM file 06
# Opened DSM file 06
# Added bounds of DTM file 06
# Accesssing 07
# Opened DTM file 07
# Opened DSM file 07
# Added bounds of DTM file 07
# Accesssing 08
# Opened DTM file 08
# Opened DSM file 08
# Added bounds of DTM file 08
# Accesssing 09
# Opened DTM file 09
# Opened DSM file 09
# Added bounds of DTM file 09
# Accesssing 10
# Opened DTM file 10
# Opened DSM file 10
# Added bounds of DTM file 10
# Accesssing 11
# Opened DTM file 11
# Opened DSM file 11
# Added bounds of DTM file 11
# Accesssing 12
# Opened DTM file 12
# Opened DSM file 12
# Added bounds of DTM file 12
# Accesssing 13
# Opened DTM file 13
# Opened DSM file 13
# Added bounds of DTM file 13
# Accesssing 14
# Opened DTM file 14
# Opened DSM file 14
# Added bounds of DTM file 14
# Accesssing 15
# Opened DTM file 15
# Opened DSM file 15
# Added bounds of DTM file 15
# Accesssing 16
# Opened DTM file 16
# Opened DSM file 16
# Added bounds of DTM file 16
# Accesssing 17
# Opened DTM file 17
# Opened DSM file 17
# Added bounds of DTM file 17
# Accesssing 18
# Opened DTM file 18
# Opened DSM file 18
# Added bounds of DTM file 18
# Accesssing 19
# Opened DTM file 19
# Opened DSM file 19
# Added bounds of DTM file 19
# Accesssing 20
# Opened DTM file 20
# Opened DSM file 20
# Added bounds of DTM file 20
# Accesssing 21
# Opened DTM file 21
# Opened DSM file 21
# Added bounds of DTM file 21
# Accesssing 22
# Opened DTM file 22
# Opened DSM file 22
# Added bounds of DTM file 22
# Accesssing 23
# Opened DTM file 23
# Opened DSM file 23
# Added bounds of DTM file 23
# Accesssing 24
# Opened DTM file 24
# Opened DSM file 24
# Added bounds of DTM file 24
# Accesssing 25
# Opened DTM file 25
# Opened DSM file 25
# Added bounds of DTM file 25
# Accesssing 26
# Opened DTM file 26
# Opened DSM file 26
# Added bounds of DTM file 26
# Accesssing 27
# Opened DTM file 27
# Opened DSM file 27
# Added bounds of DTM file 27
# Accesssing 28
# Opened DTM file 28
# Opened DSM file 28
# Added bounds of DTM file 28
# Accesssing 29
# Opened DTM file 29
# Opened DSM file 29
# Added bounds of DTM file 29
# Accesssing 30
# Opened DTM file 30
# Opened DSM file 30
# Added bounds of DTM file 30
# Accesssing 31
# Opened DTM file 31
# Opened DSM file 31
# Added bounds of DTM file 31
# Accesssing 32
# Opened DTM file 32
# Opened DSM file 32
# Added bounds of DTM file 32
# Accesssing 33
# Opened DTM file 33
# Opened DSM file 33
# Added bounds of DTM file 33
# Accesssing 34
# Opened DTM file 34
# Opened DSM file 34
# Added bounds of DTM file 34
# Accesssing 35
# Opened DTM file 35
# Opened DSM file 35
# Added bounds of DTM file 35
# Accesssing 36
# Opened DTM file 36
# Opened DSM file 36
# Added bounds of DTM file 36
# Accesssing 37
# Opened DTM file 37
# Opened DSM file 37
# Added bounds of DTM file 37
# Accesssing 38
# Opened DTM file 38
# Opened DSM file 38
# Added bounds of DTM file 38
# Accesssing 39
# Opened DTM file 39
# Opened DSM file 39
# Added bounds of DTM file 39
# Accesssing 40
# Opened DTM file 40
# Opened DSM file 40
# Added bounds of DTM file 40
# Accesssing 41
# Opened DTM file 41
# Opened DSM file 41
# Added bounds of DTM file 41
# Accesssing 42
# Opened DTM file 42
# Opened DSM file 42
# Added bounds of DTM file 42
# Accesssing 43
# Opened DTM file 43
# Opened DSM file 43
# Added bounds of DTM file 43
